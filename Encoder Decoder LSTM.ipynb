# %% [markdown]
# Basic simple encoder decoder net using a LSTM.
# Could be expanded to become a fully fledged translator.
#
# This should be able to translate any set of token pairs. The first column should contain the input and the second column the target.
#
# Improvement ideas:
# * Use embeddings instead of one hot vector representation
# * Do not pass the target to the seq2seq during evaluation
# * Try using teacher forcing some % of the time
# * Generates the max length sequence - maybe stop when hit <end>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
import csv
import matplotlib.pyplot as plt

# %%
filename = 'nums-big.txt'  # Replace with your file name

nums =[]
words=[]

with open(filename, 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        nums.append(row[0])
        words.append(row[1])

zipped = zip(nums, words)

pairs=[]
for item in zipped:
    n,w = item    
    pairs.append(["<s> "+n+" <e>","<s> "+w+" <e>"])
    
print("Num examples:", len(pairs))


# This class creates a word -> index mapping (e.g,. "dad" -> 5) and vice-versa 
# (e.g., 5 -> "dad") for each language,
class LanguageIndex():
    def __init__(self, lang):
        self.lang = lang
        self.word2idx = {}
        self.idx2word = {}
        self.vocab = set()

        self.create_index()

    def create_index(self):
        for phrase in self.lang:
            self.vocab.update(phrase.split(' '))

        self.vocab = sorted(self.vocab)

        self.word2idx['<pad>'] = 0
        
        for index, word in enumerate(self.vocab):
            self.word2idx[word] = index + 1

        for word, index in self.word2idx.items():
            self.idx2word[index] = word
            
def max_length(tensor):
    return max(len(t) for t in tensor)


import torch
from torch.nn.utils.rnn import pad_sequence

def load_dataset(pairs, num_examples):
    # pairs => already created cleaned input, output pairs

    # index language using the class defined above
    inp_lang = LanguageIndex(n for n, w in pairs)
    targ_lang = LanguageIndex(w for n, w in pairs)

    # Vectorize the input and target languages

    # Input sentences
    input_tensor = [torch.tensor([inp_lang.word2idx[s] for s in en.split(' ')], dtype=torch.long) for en, ma in pairs]

    # Target sentences
    target_tensor = [torch.tensor([targ_lang.word2idx[s] for s in ma.split(' ')], dtype=torch.long) for en, ma in pairs]

    # Calculate max_length of input and output tensor
    # Here, we'll set those to the longest sentence in the dataset
    max_length_inp, max_length_tar = max_length(input_tensor), max_length(target_tensor)

    # Padding the input and output tensor to the maximum length
    input_tensor = pad_sequence(input_tensor, batch_first=True, padding_value=0)
    input_tensor = input_tensor[:, :max_length_inp]

    target_tensor = pad_sequence(target_tensor, batch_first=True, padding_value=0)
    target_tensor = target_tensor[:, :max_length_tar]

    return input_tensor, target_tensor, inp_lang, targ_lang, max_length_inp, max_length_tar


input_tensor, target_tensor, inp_lang, targ_lang, max_length_inp, max_length_targ = load_dataset(pairs, len(pairs))

# One hot tensors -> could move to an embedding layer
oh_input = F.one_hot(input_tensor)
oh_target = F.one_hot(target_tensor)
# Out:
# Num examples: 40000

# %%
# PARAMETERS AND HYPERPARAMETERS 
INP_VOCAB_SIZE = len(inp_lang.word2idx)
TAR_VOCAB_SIZE = len(targ_lang.word2idx)
UNITS = 128 # #of units in the GRU - both encoder and decoder use this setting
INP_SEQ_LEN = max_length_inp
TAR_SEQ_LEN = max_length_targ
BATCH_SIZE = 1024

print(f"INPUT VOCAB SIZE:{INP_VOCAB_SIZE}, TARGET VOCAB SIZE: {TAR_VOCAB_SIZE}, UNITS: {UNITS},\
        INPUT SEQLEN:{INP_SEQ_LEN}, TARGET SEQ LENGTH: {TAR_SEQ_LEN}")
# Out:
# INPUT VOCAB SIZE:14, TARGET VOCAB SIZE: 34, UNITS: 128,        INPUT SEQLEN:8, TARGET SEQ LENGTH: 9

# %%
# Wrap the tensors in a TensorDataset and create the loader
dataset = TensorDataset(oh_input, oh_target)

# Split the dataset into train and eval subsets
train_size = int(0.9 * len(dataset))  # 90% for training
eval_size = len(dataset) - train_size  # 10% for evaluation
train_dataset, eval_dataset = torch.utils.data.random_split(dataset, [train_size, eval_size])

# Create DataLoaders for training and evaluation
dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
evalloader = DataLoader(eval_dataset, batch_size=BATCH_SIZE, shuffle=False)


# Encoder class 
class Encoder(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(Encoder, self).__init__()
        self.hidden_size = hidden_size
        # Encoder LSTM
        self.encoder_lstm = nn.LSTM(input_size, hidden_size, batch_first=True)   

    def forward(self, input_seq):
        # input_seq: [batch, seq, input_vocab]
        # outout : [batch, seq, units]
        # hidden: [1, seq, units] or [numlayers, seq, units]
        encoder_hidden, encoder_context = self.initialize(input_seq.shape[0])
        
        # Encoder
        encoder_output, (encoder_hidden, encoder_context) = self.encoder_lstm(input_seq, (encoder_hidden, encoder_context))
        return encoder_output, encoder_hidden, encoder_context
    
    def initialize(self, batchlen):
        return torch.zeros(1, batchlen, self.hidden_size), torch.zeros(1, batchlen, self.hidden_size)

# Decoder class
class Decoder(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(Decoder, self).__init__()
        self.hidden_size = hidden_size
        # Decoder LSTM
        self.decoder_lstm = nn.LSTM(input_size, hidden_size, batch_first=True)
        # Linear layer to map hidden state to output
        self.fc = nn.Linear(hidden_size, output_size) 

    def forward(self, input_seq, hidden, context):
        # input_seq: [batch, seq (1), input_vocab]
        # outout : [batch, seq, units]
        # hidden: [1, seq, units] or [numlayers, seq, units]

        dec_output, (dec_hidden, dec_context) = self.decoder_lstm(input_seq, (hidden, context))
        # dec_output shape: 1, seq_len, hidden_size 
        
        dec_output = self.fc(dec_output)
        # output shape: 1, seq_len, output_size
        return dec_output, dec_hidden, dec_context

    
# The Seq2Seq model to connect the encoder and decoder
class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder):
        super(Seq2Seq, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    
    def forward(self, source, target, batchsize, training):
        # The sequence we produce will be stored in this tensor
        outputs = torch.zeros(batchsize, TAR_SEQ_LEN , TAR_VOCAB_SIZE)
        #print("outputs storage shape:", outputs.shape)
        
        # Call the encoder
        enc_output, enc_hidden, enc_context = self.encoder(source)
        # enc_output shape: [batch, seq, units]
        # hidden shape: [1, seq, units] or [numlayers, seq, units] 
        
        # Grab the last time slice of the state units
        hidden = enc_hidden
        context = enc_context
        # hidden shape: [1, seq, units]
        
        # Grab the first input to the Decoder which will be the <s> token
        output = F.one_hot(torch.tensor(targ_lang.word2idx['<s>']), TAR_VOCAB_SIZE).unsqueeze(0).float()
        output = output.unsqueeze(0)
        output = output.repeat(batchsize,1,1)
        
        # Generate the full sequence -> loop could be improved to a while loop
        for t in range(TAR_SEQ_LEN):
            #if(training):
            #    #Teacher forcing only if during training
            #    x = target[:,t,:].unsqueeze(1)
            #    #print("Train x shape:", x.shape)
            #else:
            x = output

            # Use previous hidden, cell as context from encoder at start
            output, hidden, context = self.decoder(x, hidden, context)
            # output shape: 1, seq_len, output_size
            
            # Store next output prediction
            outputs[:,t,:] = output.squeeze()           
            # outputs shape: seq_len, output_size
            
        return outputs

    
# Build the model and print out some stats    
encoder = Encoder(input_size=INP_VOCAB_SIZE, hidden_size=UNITS)
decoder = Decoder(input_size=TAR_VOCAB_SIZE, hidden_size=UNITS, output_size=TAR_VOCAB_SIZE)
model = Seq2Seq(encoder, decoder)

print(sum(p.numel() for p in encoder.parameters())/1e6, 'M parameters')
print(sum(p.numel() for p in decoder.parameters())/1e6, 'M parameters')


optimizer = optim.Adam(model.parameters())
criterion = nn.CrossEntropyLoss()
# Out:
# 0.073728 M parameters
# 0.088354 M parameters

# %%
# Training phase

# for param_group in optimizer.param_groups:
#     param_group['lr'] = 0.01

bsize = 1

EPOCHS = 10
model.train()

step = 0
stepi = []
lossi = []

for e in range(EPOCHS):    
    
    for index, (inp, targ) in enumerate(dataloader):
        loss =0 
        bsize = inp.shape[0]
        
        output = model(inp.float(), targ.float(), bsize, 1)
        
        #print("model output:", output.shape)
        output = output.squeeze(1)
        targ = torch.argmax(targ, dim=2).squeeze(0)
        
        outr = output.view(-1,TAR_VOCAB_SIZE)
        tarr = targ.view(-1)
        loss += criterion(outr,tarr)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        stepi.append(step)
        lossi.append(loss.item())
        step += 1

        
    if(e%(EPOCHS/10)==0):
        print("Loss:", loss.item())

    # Training time ...

plt.plot(stepi,lossi)    

print("Done!")
# Out:
# Loss: 0.03975207358598709
# Loss: 0.1595737189054489
# Loss: 0.05631440132856369
# Loss: 0.04444258660078049
# Loss: 0.04633919894695282
# Loss: 0.039530009031295776
# Loss: 0.036661792546510696
# Loss: 0.036950767040252686
# Loss: 0.03238679841160774
# Loss: 0.030313385650515556
# Done!

# %%
# Evaluation phase
count = 0

for index, (inp, targ) in enumerate(evalloader):

    correct = 0 
    bsize = inp.shape[0]
    output = model(inp.float(), targ.float(), bsize, 0)

    #print("model output:", output.shape)
    output = output.squeeze(1)
    targ = torch.argmax(targ, dim=2).squeeze(0)

    outr = output.view(-1,TAR_VOCAB_SIZE)
    tarr = targ.view(-1)
    loss += criterion(outr,tarr)

    omax = torch.argmax(output, dim=2)
    imax = torch.argmax(inp, dim=2)

    outr = output.reshape(-1,TAR_VOCAB_SIZE)
    tarr = targ.view(-1)

    for b in range(bsize):

        print("\nI: ", end="")
        for i in range(INP_SEQ_LEN):
            print(inp_lang.idx2word[imax[b][i].item()] + " ", end='')

        print("\nP: ", end="")
        pout = ""
        for t in range(TAR_SEQ_LEN):
            pout += targ_lang.idx2word[omax[b][t].item()] +" "
        print(pout + " ", end="")

        label = ""
        print("\nT: ", end="")
        for s in range(TAR_SEQ_LEN):
            label += targ_lang.idx2word[targ[b][s].item()] + " "
        print(label + " ", end="")
                                      
        if( pout == label ):
            correct += 1
            print(" Ding!", end="")

        print()

print(f"\n\n Correct: {correct}, Total: {bsize}, Acuuracy: {correct/bsize}")
# Out:
# I: <s> 3 4 0 1 0  <e>
# P: <s> thirty four thousand ten <e> <pad> <pad> <pad>
# T: <s> thirty four thousand ten <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 2 5 3 2  <e> <pad>
# P: <s> two thousand five hundred thirty two <e> <pad>
# T: <s> two thousand five hundred thirty two <e> <pad>   Ding!
#
# I: <s> 2 8 0 5 8  <e>
# P: <s> twenty eight thousand eighty eight <e> <pad> <pad>
# T: <s> twenty eight thousand fifty eight <e> <pad> <pad>
#
# I: <s> 4 1 6 5  <e> <pad>
# P: <s> four thousand one hundred sixty five <e> <pad>
# T: <s> four thousand one hundred sixty five <e> <pad>   Ding!
#
# I: <s> 3 3 1 5 4  <e>
# P: <s> thirty three thousand one hundred fifty four <e>
# T: <s> thirty three thousand one hundred fifty four <e>   Ding!
#
# I: <s> 4 0 2 9  <e> <pad>
# P: <s> four thousand twenty nine <e> <pad> <pad> <pad>
# T: <s> four thousand twenty nine <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 3 2 5 5 0  <e>
# P: <s> thirty two thousand five hundred fifty  <e>
# T: <s> thirty two thousand five hundred fifty  <e>   Ding!
#
# I: <s> 2 5 1 6 3  <e>
# P: <s> twenty five thousand one hundred sixty three <e>
# T: <s> twenty five thousand one hundred sixty three <e>   Ding!
#
# I: <s> 5 0 8 3  <e> <pad>
# P: <s> five thousand eighty three <e> <pad> <pad> <pad>
# T: <s> five thousand eighty three <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 3 9 5 9 6  <e>
# P: <s> thirty nine thousand five hundred ninety six <e>
# T: <s> thirty nine thousand five hundred ninety six <e>   Ding!
#
# I: <s> 4 6 0 3  <e> <pad>
# P: <s> four thousand six hundred three <e> <pad> <pad>
# T: <s> four thousand six hundred three <e> <pad> <pad>   Ding!
#
# I: <s> 1 8 1 1 8  <e>
# P: <s> eighteen thousand one hundred eighteen <e> <pad> <pad>
# T: <s> eighteen thousand one hundred eighteen <e> <pad> <pad>   Ding!
#
# I: <s> 1 5 8 6 5  <e>
# P: <s> fifteen thousand eight hundred sixty five <e> <pad>
# T: <s> fifteen thousand eight hundred sixty five <e> <pad>   Ding!
#
# I: <s> 1 7 3 1 9  <e>
# P: <s> seventeen thousand three hundred nineteen <e> <pad> <pad>
# T: <s> seventeen thousand three hundred nineteen <e> <pad> <pad>   Ding!
#
# I: <s> 1 3 9 9 5  <e>
# P: <s> thirteen thousand nine hundred ninety five <e> <pad>
# T: <s> thirteen thousand nine hundred ninety five <e> <pad>   Ding!
#
# I: <s> 3 6 7 7  <e> <pad>
# P: <s> three thousand six hundred seventy seven <e> <pad>
# T: <s> three thousand six hundred seventy seven <e> <pad>   Ding!
#
# I: <s> 1 5 4 6 0  <e>
# P: <s> fifteen thousand four hundred sixty  <e> <pad>
# T: <s> fifteen thousand four hundred sixty  <e> <pad>   Ding!
#
# I: <s> 3 5 4 0 5  <e>
# P: <s> thirty five thousand four hundred five <e> <pad>
# T: <s> thirty five thousand four hundred five <e> <pad>   Ding!
#
# I: <s> 1 7 2 5  <e> <pad>
# P: <s> one thousand seven hundred twenty five <e> <pad>
# T: <s> one thousand seven hundred twenty five <e> <pad>   Ding!
#
# I: <s> 2 0 8 7 4  <e>
# P: <s> twenty  thousand eight hundred seventy four <e>
# T: <s> twenty  thousand eight hundred seventy four <e>   Ding!
#
# I: <s> 1 9 5 7 2  <e>
# P: <s> nineteen thousand five hundred seventy two <e> <pad>
# T: <s> nineteen thousand five hundred seventy two <e> <pad>   Ding!
#
# I: <s> 3 1 5 6  <e> <pad>
# P: <s> three thousand one hundred fifty six <e> <pad>
# T: <s> three thousand one hundred fifty six <e> <pad>   Ding!
#
# I: <s> 3 5 0 9 0  <e>
# P: <s> thirty five thousand ninety  <e> <pad> <pad>
# T: <s> thirty five thousand ninety  <e> <pad> <pad>   Ding!
#
# I: <s> 2 7 7 0 1  <e>
# P: <s> twenty seven thousand seven hundred one <e> <pad>
# T: <s> twenty seven thousand seven hundred one <e> <pad>   Ding!
#
# I: <s> 2 5 0 8 4  <e>
# P: <s> twenty five thousand eighty four <e> <pad> <pad>
# T: <s> twenty five thousand eighty four <e> <pad> <pad>   Ding!
#
# I: <s> 2 7 1 4 3  <e>
# P: <s> twenty seven thousand one hundred forty three <e>
# T: <s> twenty seven thousand one hundred forty three <e>   Ding!
#
# I: <s> 3 4 8 1 5  <e>
# P: <s> thirty four thousand eight hundred fifteen <e> <pad>
# T: <s> thirty four thousand eight hundred fifteen <e> <pad>   Ding!
#
# I: <s> 3 8 1 2 6  <e>
# P: <s> thirty eight thousand one hundred twenty six <e>
# T: <s> thirty eight thousand one hundred twenty six <e>   Ding!
#
# I: <s> 2 8 8 0 1  <e>
# P: <s> twenty eight thousand eight hundred one <e> <pad>
# T: <s> twenty eight thousand eight hundred one <e> <pad>   Ding!
#
# I: <s> 7 8 8  <e> <pad> <pad>
# P: <s> seven hundred eighty eight <e> <pad> <pad> <pad>
# T: <s> seven hundred eighty eight <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 1 7 0 1 6  <e>
# P: <s> seventeen thousand sixteen <e> <pad> <pad> <pad> <pad>
# T: <s> seventeen thousand sixteen <e> <pad> <pad> <pad> <pad>   Ding!
#
# I: <s> 1 4 0 7 9  <e>
# P: <s> fourteen thousand seventy nine <e> <pad> <pad> <pad>
# T: <s> fourteen thousand seventy nine <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 5 0 2 7  <e> <pad>
# P: <s> five thousand twenty seven <e> <pad> <pad> <pad>
# T: <s> five thousand twenty seven <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 2 2 2 9 0  <e>
# P: <s> twenty two thousand two hundred ninety  <e>
# T: <s> twenty two thousand two hundred ninety  <e>   Ding!
#
# I: <s> 2 2 0 9 4  <e>
# P: <s> twenty two thousand ninety four <e> <pad> <pad>
# T: <s> twenty two thousand ninety four <e> <pad> <pad>   Ding!
#
# I: <s> 3 1 5 2 0  <e>
# P: <s> thirty one thousand five hundred twenty  <e>
# T: <s> thirty one thousand five hundred twenty  <e>   Ding!
#
# I: <s> 9 5 9 7  <e> <pad>
# P: <s> nine thousand five hundred ninety seven <e> <pad>
# T: <s> nine thousand five hundred ninety seven <e> <pad>   Ding!
#
# I: <s> 2 5 3 8 6  <e>
# P: <s> twenty five thousand three hundred eighty six <e>
# T: <s> twenty five thousand three hundred eighty six <e>   Ding!
#
# I: <s> 1 0 9 5 8  <e>
# P: <s> ten thousand nine hundred fifty eight <e> <pad>
# T: <s> ten thousand nine hundred fifty eight <e> <pad>   Ding!
#
# I: <s> 5 8 8 0  <e> <pad>
# P: <s> five thousand eight hundred eighty  <e> <pad>
# T: <s> five thousand eight hundred eighty  <e> <pad>   Ding!
#
# I: <s> 1 9 5 3 5  <e>
# P: <s> nineteen thousand five hundred thirty five <e> <pad>
# T: <s> nineteen thousand five hundred thirty five <e> <pad>   Ding!
#
# I: <s> 3 6 2 4 8  <e>
# P: <s> thirty six thousand two hundred forty eight <e>
# T: <s> thirty six thousand two hundred forty eight <e>   Ding!
#
# I: <s> 3 0 9 9 9  <e>
# P: <s> thirty  thousand nine hundred ninety nine <e>
# T: <s> thirty  thousand nine hundred ninety nine <e>   Ding!
#
# I: <s> 3 2 0 6 6  <e>
# P: <s> thirty two thousand sixty six <e> <pad> <pad>
# T: <s> thirty two thousand sixty six <e> <pad> <pad>   Ding!
#
# I: <s> 2 6  <e> <pad> <pad> <pad>
# P: <s> twenty six <e> <pad> <pad> <pad> <pad> <pad>
# T: <s> twenty six <e> <pad> <pad> <pad> <pad> <pad>   Ding!
#
# I: <s> 2 3 8 1 3  <e>
# P: <s> twenty three thousand eight hundred thirteen <e> <pad>
# T: <s> twenty three thousand eight hundred thirteen <e> <pad>   Ding!
#
# I: <s> 3 3 9 1 2  <e>
# P: <s> thirty three thousand nine hundred twelve <e> <pad>
# T: <s> thirty three thousand nine hundred twelve <e> <pad>   Ding!
#
# I: <s> 2 1 7 9 1  <e>
# P: <s> twenty one thousand seven hundred ninety one <e>
# T: <s> twenty one thousand seven hundred ninety one <e>   Ding!
#
# I: <s> 6 3 7  <e> <pad> <pad>
# P: <s> six hundred thirty seven <e> <pad> <pad> <pad>
# T: <s> six hundred thirty seven <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 1 6 2 2 8  <e>
# P: <s> sixteen thousand two hundred twenty eight <e> <pad>
# T: <s> sixteen thousand two hundred twenty eight <e> <pad>   Ding!
#
# I: <s> 1 7 4 6 0  <e>
# P: <s> seventeen thousand four hundred sixty  <e> <pad>
# T: <s> seventeen thousand four hundred sixty  <e> <pad>   Ding!
#
# I: <s> 1 9 9 4 1  <e>
# P: <s> nineteen thousand nine hundred forty one <e> <pad>
# T: <s> nineteen thousand nine hundred forty one <e> <pad>   Ding!
#
# I: <s> 2 5 5 1 9  <e>
# P: <s> twenty five thousand five hundred nineteen <e> <pad>
# T: <s> twenty five thousand five hundred nineteen <e> <pad>   Ding!
#
# I: <s> 2 4 0 8 1  <e>
# P: <s> twenty four thousand eighty one <e> <pad> <pad>
# T: <s> twenty four thousand eighty one <e> <pad> <pad>   Ding!
#
# I: <s> 1 4 7 9 2  <e>
# P: <s> fourteen thousand seven hundred ninety two <e> <pad>
# T: <s> fourteen thousand seven hundred ninety two <e> <pad>   Ding!
#
# I: <s> 2 5 1 4 8  <e>
# P: <s> twenty five thousand one hundred forty eight <e>
# T: <s> twenty five thousand one hundred forty eight <e>   Ding!
#
# I: <s> 3 2 6 9 1  <e>
# P: <s> thirty two thousand six hundred ninety one <e>
# T: <s> thirty two thousand six hundred ninety one <e>   Ding!
#
# I: <s> 1 1 1 5  <e> <pad>
# P: <s> one thousand one hundred fifteen <e> <pad> <pad>
# T: <s> one thousand one hundred fifteen <e> <pad> <pad>   Ding!
#
# I: <s> 2 8 8 4 0  <e>
# P: <s> twenty eight thousand eight hundred forty  <e>
# T: <s> twenty eight thousand eight hundred forty  <e>   Ding!
#
# I: <s> 1 0 5 5 2  <e>
# P: <s> ten thousand five hundred fifty two <e> <pad>
# T: <s> ten thousand five hundred fifty two <e> <pad>   Ding!
#
# I: <s> 7 7 3  <e> <pad> <pad>
# P: <s> seven hundred seventy three <e> <pad> <pad> <pad>
# T: <s> seven hundred seventy three <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 2 9 9 3 5  <e>
# P: <s> twenty nine thousand nine hundred thirty five <e>
# T: <s> twenty nine thousand nine hundred thirty five <e>   Ding!
#
# I: <s> 3 9 2 0 3  <e>
# P: <s> thirty nine thousand two hundred three <e> <pad>
# T: <s> thirty nine thousand two hundred three <e> <pad>   Ding!
#
# I: <s> 3 5 5 7 1  <e>
# P: <s> thirty five thousand five hundred seventy one <e>
# T: <s> thirty five thousand five hundred seventy one <e>   Ding!
#
# I: <s> 6 0 9 6  <e> <pad>
# P: <s> six thousand ninety six <e> <pad> <pad> <pad>
# T: <s> six thousand ninety six <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 3 3 2 0 6  <e>
# P: <s> thirty three thousand two hundred six <e> <pad>
# T: <s> thirty three thousand two hundred six <e> <pad>   Ding!
#
# I: <s> 1 6 9 8  <e> <pad>
# P: <s> one thousand six hundred ninety eight <e> <pad>
# T: <s> one thousand six hundred ninety eight <e> <pad>   Ding!
#
# I: <s> 2 7 5 5 5  <e>
# P: <s> twenty seven thousand five hundred fifty five <e>
# T: <s> twenty seven thousand five hundred fifty five <e>   Ding!
#
# I: <s> 2 2 6 1  <e> <pad>
# P: <s> two thousand two hundred sixty one <e> <pad>
# T: <s> two thousand two hundred sixty one <e> <pad>   Ding!
#
# I: <s> 7 3 2  <e> <pad> <pad>
# P: <s> seven hundred thirty two <e> <pad> <pad> <pad>
# T: <s> seven hundred thirty two <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 1 9 6 3 9  <e>
# P: <s> nineteen thousand six hundred thirty nine <e> <pad>
# T: <s> nineteen thousand six hundred thirty nine <e> <pad>   Ding!
#
# I: <s> 9 2 2 6  <e> <pad>
# P: <s> nine thousand two hundred twenty six <e> <pad>
# T: <s> nine thousand two hundred twenty six <e> <pad>   Ding!
#
# I: <s> 1 7 2 5 9  <e>
# P: <s> seventeen thousand two hundred fifty nine <e> <pad>
# T: <s> seventeen thousand two hundred fifty nine <e> <pad>   Ding!
#
# I: <s> 2 6 5 2 5  <e>
# P: <s> twenty six thousand five hundred twenty five <e>
# T: <s> twenty six thousand five hundred twenty five <e>   Ding!
#
# I: <s> 1 8 1 4 4  <e>
# P: <s> eighteen thousand one hundred forty four <e> <pad>
# T: <s> eighteen thousand one hundred forty four <e> <pad>   Ding!
#
# I: <s> 3 9 1 1 8  <e>
# P: <s> thirty nine thousand one hundred eighteen <e> <pad>
# T: <s> thirty nine thousand one hundred eighteen <e> <pad>   Ding!
#
# I: <s> 2 7 9 2 6  <e>
# P: <s> twenty seven thousand nine hundred twenty six <e>
# T: <s> twenty seven thousand nine hundred twenty six <e>   Ding!
#
# I: <s> 2 5 8 3 8  <e>
# P: <s> twenty five thousand eight hundred thirty eight <e>
# T: <s> twenty five thousand eight hundred thirty eight <e>   Ding!
#
# I: <s> 3 8 1 9 9  <e>
# P: <s> thirty eight thousand one hundred ninety nine <e>
# T: <s> thirty eight thousand one hundred ninety nine <e>   Ding!
#
# I: <s> 1 5 2 3 4  <e>
# P: <s> fifteen thousand two hundred thirty four <e> <pad>
# T: <s> fifteen thousand two hundred thirty four <e> <pad>   Ding!
#
# I: <s> 1 9 3 3 7  <e>
# P: <s> nineteen thousand three hundred thirty seven <e> <pad>
# T: <s> nineteen thousand three hundred thirty seven <e> <pad>   Ding!
#
# I: <s> 9 9 1 6  <e> <pad>
# P: <s> nine thousand nine hundred sixteen <e> <pad> <pad>
# T: <s> nine thousand nine hundred sixteen <e> <pad> <pad>   Ding!
#
# I: <s> 2 3 9 2 8  <e>
# P: <s> twenty three thousand nine hundred twenty eight <e>
# T: <s> twenty three thousand nine hundred twenty eight <e>   Ding!
#
# I: <s> 1 6 0 6 3  <e>
# P: <s> sixteen thousand sixty three <e> <pad> <pad> <pad>
# T: <s> sixteen thousand sixty three <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 2 5 8 8 2  <e>
# P: <s> twenty five thousand eight hundred eighty two <e>
# T: <s> twenty five thousand eight hundred eighty two <e>   Ding!
#
# I: <s> 3 3 3 1 6  <e>
# P: <s> thirty three thousand three hundred sixteen <e> <pad>
# T: <s> thirty three thousand three hundred sixteen <e> <pad>   Ding!
#
# I: <s> 3 7 9 7 5  <e>
# P: <s> thirty seven thousand nine hundred seventy five <e>
# T: <s> thirty seven thousand nine hundred seventy five <e>   Ding!
#
# I: <s> 2 1 6 7 4  <e>
# P: <s> twenty one thousand six hundred seventy four <e>
# T: <s> twenty one thousand six hundred seventy four <e>   Ding!
#
# I: <s> 3 3 9 8 6  <e>
# P: <s> thirty three thousand nine hundred eighty six <e>
# T: <s> thirty three thousand nine hundred eighty six <e>   Ding!
#
# I: <s> 2 5 6 1 8  <e>
# P: <s> twenty five thousand six hundred eighteen <e> <pad>
# T: <s> twenty five thousand six hundred eighteen <e> <pad>   Ding!
#
# I: <s> 9 9 2 2  <e> <pad>
# P: <s> nine thousand nine hundred twenty two <e> <pad>
# T: <s> nine thousand nine hundred twenty two <e> <pad>   Ding!
#
# I: <s> 1 4 8 2 0  <e>
# P: <s> fourteen thousand eight hundred twenty  <e> <pad>
# T: <s> fourteen thousand eight hundred twenty  <e> <pad>   Ding!
#
# I: <s> 3 6 6 5  <e> <pad>
# P: <s> three thousand six hundred sixty five <e> <pad>
# T: <s> three thousand six hundred sixty five <e> <pad>   Ding!
#
# I: <s> 2 7 0 2 7  <e>
# P: <s> twenty seven thousand twenty seven <e> <pad> <pad>
# T: <s> twenty seven thousand twenty seven <e> <pad> <pad>   Ding!
#
# I: <s> 2 9 1 9 6  <e>
# P: <s> twenty nine thousand one hundred ninety six <e>
# T: <s> twenty nine thousand one hundred ninety six <e>   Ding!
#
# I: <s> 3 9 9 1 2  <e>
# P: <s> thirty nine thousand nine hundred twelve <e> <pad>
# T: <s> thirty nine thousand nine hundred twelve <e> <pad>   Ding!
#
# I: <s> 7 6 1 0  <e> <pad>
# P: <s> seven thousand six hundred ten <e> <pad> <pad>
# T: <s> seven thousand six hundred ten <e> <pad> <pad>   Ding!
#
# I: <s> 5 0 5  <e> <pad> <pad>
# P: <s> five hundred five <e> <pad> <pad> <pad> <pad>
# T: <s> five hundred five <e> <pad> <pad> <pad> <pad>   Ding!
#
# I: <s> 9 4 5 3  <e> <pad>
# P: <s> nine thousand four hundred fifty three <e> <pad>
# T: <s> nine thousand four hundred fifty three <e> <pad>   Ding!
#
# I: <s> 3 2 2 2 8  <e>
# P: <s> thirty two thousand two hundred twenty eight <e>
# T: <s> thirty two thousand two hundred twenty eight <e>   Ding!
#
# I: <s> 4 9 4 0  <e> <pad>
# P: <s> four thousand nine hundred forty  <e> <pad>
# T: <s> four thousand nine hundred forty  <e> <pad>   Ding!
#
# I: <s> 2 1 1 5 0  <e>
# P: <s> twenty one thousand one hundred fifty  <e>
# T: <s> twenty one thousand one hundred fifty  <e>   Ding!
#
# I: <s> 4 2 4 0  <e> <pad>
# P: <s> four thousand two hundred forty  <e> <pad>
# T: <s> four thousand two hundred forty  <e> <pad>   Ding!
#
# I: <s> 3 2 9 4 8  <e>
# P: <s> thirty two thousand nine hundred forty eight <e>
# T: <s> thirty two thousand nine hundred forty eight <e>   Ding!
#
# I: <s> 2 8 0 5 4  <e>
# P: <s> twenty eight thousand fifty four <e> <pad> <pad>
# T: <s> twenty eight thousand fifty four <e> <pad> <pad>   Ding!
#
# I: <s> 2 0 7 8 4  <e>
# P: <s> twenty  thousand seven hundred eighty four <e>
# T: <s> twenty  thousand seven hundred eighty four <e>   Ding!
#
# I: <s> 3 9 3 8 6  <e>
# P: <s> thirty nine thousand three hundred eighty six <e>
# T: <s> thirty nine thousand three hundred eighty six <e>   Ding!
#
# I: <s> 1 8 7 5  <e> <pad>
# P: <s> one thousand eight hundred seventy five <e> <pad>
# T: <s> one thousand eight hundred seventy five <e> <pad>   Ding!
#
# I: <s> 1 0 1 2  <e> <pad>
# P: <s> one thousand twelve <e> <pad> <pad> <pad> <pad>
# T: <s> one thousand twelve <e> <pad> <pad> <pad> <pad>   Ding!
#
# I: <s> 5 8 7 7  <e> <pad>
# P: <s> five thousand eight hundred seventy seven <e> <pad>
# T: <s> five thousand eight hundred seventy seven <e> <pad>   Ding!
#
# I: <s> 2 4 2 9 5  <e>
# P: <s> twenty four thousand two hundred ninety five <e>
# T: <s> twenty four thousand two hundred ninety five <e>   Ding!
#
# I: <s> 1 2 7 9 6  <e>
# P: <s> twelve thousand seven hundred ninety six <e> <pad>
# T: <s> twelve thousand seven hundred ninety six <e> <pad>   Ding!
#
# I: <s> 5  <e> <pad> <pad> <pad> <pad>
# P: <s> three <e> <pad> <pad> <pad> <pad> <pad> <pad>
# T: <s> five <e> <pad> <pad> <pad> <pad> <pad> <pad>
#
# I: <s> 2 0 4 0 5  <e>
# P: <s> twenty  thousand four hundred five <e> <pad>
# T: <s> twenty  thousand four hundred five <e> <pad>   Ding!
#
# I: <s> 1 3 1 9 2  <e>
# P: <s> thirteen thousand one hundred ninety two <e> <pad>
# T: <s> thirteen thousand one hundred ninety two <e> <pad>   Ding!
#
# I: <s> 2 6 4 0 7  <e>
# P: <s> twenty six thousand four hundred seven <e> <pad>
# T: <s> twenty six thousand four hundred seven <e> <pad>   Ding!
#
# I: <s> 3 3 5 2 2  <e>
# P: <s> thirty three thousand five hundred twenty two <e>
# T: <s> thirty three thousand five hundred twenty two <e>   Ding!
#
# I: <s> 3 7 1 6 7  <e>
# P: <s> thirty seven thousand one hundred seventy seven <e>
# T: <s> thirty seven thousand one hundred sixty seven <e>
#
# I: <s> 3 9 1 4 1  <e>
# P: <s> thirty nine thousand one hundred forty one <e>
# T: <s> thirty nine thousand one hundred forty one <e>   Ding!
#
# I: <s> 2 0 6 9 4  <e>
# P: <s> twenty  thousand six hundred ninety four <e>
# T: <s> twenty  thousand six hundred ninety four <e>   Ding!
#
# I: <s> 1 7 7 4 5  <e>
# P: <s> seventeen thousand seven hundred forty five <e> <pad>
# T: <s> seventeen thousand seven hundred forty five <e> <pad>   Ding!
#
# I: <s> 1 0 0 2 2  <e>
# P: <s> ten thousand twenty two <e> <pad> <pad> <pad>
# T: <s> ten thousand twenty two <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 4 9 4 5  <e> <pad>
# P: <s> four thousand nine hundred forty five <e> <pad>
# T: <s> four thousand nine hundred forty five <e> <pad>   Ding!
#
# I: <s> 1 3 1 9 8  <e>
# P: <s> thirteen thousand one hundred ninety eight <e> <pad>
# T: <s> thirteen thousand one hundred ninety eight <e> <pad>   Ding!
#
# I: <s> 1 8 5 1 8  <e>
# P: <s> eighteen thousand five hundred eighteen <e> <pad> <pad>
# T: <s> eighteen thousand five hundred eighteen <e> <pad> <pad>   Ding!
#
# I: <s> 3 6 4 2 3  <e>
# P: <s> thirty six thousand four hundred twenty three <e>
# T: <s> thirty six thousand four hundred twenty three <e>   Ding!
#
# I: <s> 3 0 7 2 7  <e>
# P: <s> thirty  thousand seven hundred twenty seven <e>
# T: <s> thirty  thousand seven hundred twenty seven <e>   Ding!
#
# I: <s> 1 4 9 4 0  <e>
# P: <s> fourteen thousand nine hundred forty  <e> <pad>
# T: <s> fourteen thousand nine hundred forty  <e> <pad>   Ding!
#
# I: <s> 5 5 8 5  <e> <pad>
# P: <s> five thousand five hundred fifty eight <e> <pad>
# T: <s> five thousand five hundred eighty five <e> <pad>
#
# I: <s> 3 6 0 3 6  <e>
# P: <s> thirty six thousand thirty six <e> <pad> <pad>
# T: <s> thirty six thousand thirty six <e> <pad> <pad>   Ding!
#
# I: <s> 1 5 0 5 2  <e>
# P: <s> fifteen thousand fifty two <e> <pad> <pad> <pad>
# T: <s> fifteen thousand fifty two <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 3 6 2 2 3  <e>
# P: <s> thirty six thousand two hundred twenty three <e>
# T: <s> thirty six thousand two hundred twenty three <e>   Ding!
#
# I: <s> 2 1 6 0 5  <e>
# P: <s> twenty one thousand six hundred five <e> <pad>
# T: <s> twenty one thousand six hundred five <e> <pad>   Ding!
#
# I: <s> 2 9 5 5  <e> <pad>
# P: <s> two thousand nine hundred fifty five <e> <pad>
# T: <s> two thousand nine hundred fifty five <e> <pad>   Ding!
#
# I: <s> 1 9 5 5 0  <e>
# P: <s> nineteen thousand five hundred fifty  <e> <pad>
# T: <s> nineteen thousand five hundred fifty  <e> <pad>   Ding!
#
# I: <s> 5 4 9 9  <e> <pad>
# P: <s> five thousand four hundred ninety nine <e> <pad>
# T: <s> five thousand four hundred ninety nine <e> <pad>   Ding!
#
# I: <s> 1 1 0 0 8  <e>
# P: <s> eleven thousand eight <e> <pad> <pad> <pad> <pad>
# T: <s> eleven thousand eight <e> <pad> <pad> <pad> <pad>   Ding!
#
# I: <s> 2 3 7 6 8  <e>
# P: <s> twenty three thousand seven hundred seventy eight <e>
# T: <s> twenty three thousand seven hundred sixty eight <e>
#
# I: <s> 2 0 7 5 0  <e>
# P: <s> twenty  thousand seven hundred fifty  <e>
# T: <s> twenty  thousand seven hundred fifty  <e>   Ding!
#
# I: <s> 3 5 3 6 4  <e>
# P: <s> thirty five thousand three hundred sixty four <e>
# T: <s> thirty five thousand three hundred sixty four <e>   Ding!
#
# I: <s> 2 1 3 4 5  <e>
# P: <s> twenty one thousand three hundred forty five <e>
# T: <s> twenty one thousand three hundred forty five <e>   Ding!
#
# I: <s> 1 0 3 6  <e> <pad>
# P: <s> one thousand thirty six <e> <pad> <pad> <pad>
# T: <s> one thousand thirty six <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 7 5 2 1  <e> <pad>
# P: <s> seven thousand five hundred twenty one <e> <pad>
# T: <s> seven thousand five hundred twenty one <e> <pad>   Ding!
#
# I: <s> 2 7 0 1 8  <e>
# P: <s> twenty seven thousand eighteen <e> <pad> <pad> <pad>
# T: <s> twenty seven thousand eighteen <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 3 2 3 3 8  <e>
# P: <s> thirty two thousand three hundred thirty eight <e>
# T: <s> thirty two thousand three hundred thirty eight <e>   Ding!
#
# I: <s> 3 8 3 4 5  <e>
# P: <s> thirty eight thousand three hundred forty five <e>
# T: <s> thirty eight thousand three hundred forty five <e>   Ding!
#
# I: <s> 2 5 7 8 7  <e>
# P: <s> twenty five thousand seven hundred eighty seven <e>
# T: <s> twenty five thousand seven hundred eighty seven <e>   Ding!
#
# I: <s> 1 3 1 8 6  <e>
# P: <s> thirteen thousand one hundred eighty six <e> <pad>
# T: <s> thirteen thousand one hundred eighty six <e> <pad>   Ding!
#
# I: <s> 3 5 7 8  <e> <pad>
# P: <s> three thousand five hundred seventy eight <e> <pad>
# T: <s> three thousand five hundred seventy eight <e> <pad>   Ding!
#
# I: <s> 3 2 5 1 0  <e>
# P: <s> thirty two thousand five hundred ten <e> <pad>
# T: <s> thirty two thousand five hundred ten <e> <pad>   Ding!
#
# I: <s> 2 3 1 6 7  <e>
# P: <s> twenty three thousand one hundred sixty seven <e>
# T: <s> twenty three thousand one hundred sixty seven <e>   Ding!
#
# I: <s> 3 3 3 5 7  <e>
# P: <s> thirty three thousand three hundred fifty seven <e>
# T: <s> thirty three thousand three hundred fifty seven <e>   Ding!
#
# I: <s> 3 9 0 2 3  <e>
# P: <s> thirty nine thousand twenty three <e> <pad> <pad>
# T: <s> thirty nine thousand twenty three <e> <pad> <pad>   Ding!
#
# I: <s> 1 6 6 1 3  <e>
# P: <s> sixteen thousand six hundred thirteen <e> <pad> <pad>
# T: <s> sixteen thousand six hundred thirteen <e> <pad> <pad>   Ding!
#
# I: <s> 1 9 0 3 3  <e>
# P: <s> nineteen thousand thirty three <e> <pad> <pad> <pad>
# T: <s> nineteen thousand thirty three <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 2 1 0 1 1  <e>
# P: <s> twenty one thousand eleven <e> <pad> <pad> <pad>
# T: <s> twenty one thousand eleven <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 3 4 7 8 7  <e>
# P: <s> thirty four thousand seven hundred eighty seven <e>
# T: <s> thirty four thousand seven hundred eighty seven <e>   Ding!
#
# I: <s> 1 2 1 6 9  <e>
# P: <s> twelve thousand one hundred sixty nine <e> <pad>
# T: <s> twelve thousand one hundred sixty nine <e> <pad>   Ding!
#
# I: <s> 4 2 8 0  <e> <pad>
# P: <s> four thousand two hundred eighty  <e> <pad>
# T: <s> four thousand two hundred eighty  <e> <pad>   Ding!
#
# I: <s> 8 3 5 6  <e> <pad>
# P: <s> eight thousand three hundred fifty six <e> <pad>
# T: <s> eight thousand three hundred fifty six <e> <pad>   Ding!
#
# I: <s> 3 3 6 9  <e> <pad>
# P: <s> three thousand three hundred sixty nine <e> <pad>
# T: <s> three thousand three hundred sixty nine <e> <pad>   Ding!
#
# I: <s> 6 6 7 3  <e> <pad>
# P: <s> six thousand six hundred seventy three <e> <pad>
# T: <s> six thousand six hundred seventy three <e> <pad>   Ding!
#
# I: <s> 1 1 2 4 8  <e>
# P: <s> eleven thousand two hundred forty eight <e> <pad>
# T: <s> eleven thousand two hundred forty eight <e> <pad>   Ding!
#
# I: <s> 1 2 4 4 7  <e>
# P: <s> twelve thousand four hundred forty seven <e> <pad>
# T: <s> twelve thousand four hundred forty seven <e> <pad>   Ding!
#
# I: <s> 3 1 6 3  <e> <pad>
# P: <s> three thousand one hundred sixty three <e> <pad>
# T: <s> three thousand one hundred sixty three <e> <pad>   Ding!
#
# I: <s> 2 9 8 3 9  <e>
# P: <s> twenty nine thousand eight hundred thirty nine <e>
# T: <s> twenty nine thousand eight hundred thirty nine <e>   Ding!
#
# I: <s> 1 7 4 5 9  <e>
# P: <s> seventeen thousand four hundred fifty nine <e> <pad>
# T: <s> seventeen thousand four hundred fifty nine <e> <pad>   Ding!
#
# I: <s> 3 5 0 2 6  <e>
# P: <s> thirty five thousand twenty six <e> <pad> <pad>
# T: <s> thirty five thousand twenty six <e> <pad> <pad>   Ding!
#
# I: <s> 4 7 4 5  <e> <pad>
# P: <s> four thousand seven hundred forty five <e> <pad>
# T: <s> four thousand seven hundred forty five <e> <pad>   Ding!
#
# I: <s> 2 8 4 4 3  <e>
# P: <s> twenty eight thousand four hundred forty three <e>
# T: <s> twenty eight thousand four hundred forty three <e>   Ding!
#
# I: <s> 3 5 3 1  <e> <pad>
# P: <s> three thousand five hundred thirty one <e> <pad>
# T: <s> three thousand five hundred thirty one <e> <pad>   Ding!
#
# I: <s> 3 7 4 8 7  <e>
# P: <s> thirty seven thousand four hundred eighty seven <e>
# T: <s> thirty seven thousand four hundred eighty seven <e>   Ding!
#
# I: <s> 2 0 4 9 1  <e>
# P: <s> twenty  thousand four hundred ninety one <e>
# T: <s> twenty  thousand four hundred ninety one <e>   Ding!
#
# I: <s> 1 0 0 1 6  <e>
# P: <s> ten thousand sixteen <e> <pad> <pad> <pad> <pad>
# T: <s> ten thousand sixteen <e> <pad> <pad> <pad> <pad>   Ding!
#
# I: <s> 3 6 2 9 5  <e>
# P: <s> thirty six thousand two hundred ninety five <e>
# T: <s> thirty six thousand two hundred ninety five <e>   Ding!
#
# I: <s> 7 0 7 3  <e> <pad>
# P: <s> seven thousand seventy three <e> <pad> <pad> <pad>
# T: <s> seven thousand seventy three <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 2 0 3 3 2  <e>
# P: <s> twenty  thousand three hundred twenty two <e>
# T: <s> twenty  thousand three hundred thirty two <e>
#
# I: <s> 2 6 5 9  <e> <pad>
# P: <s> two thousand six hundred fifty nine <e> <pad>
# T: <s> two thousand six hundred fifty nine <e> <pad>   Ding!
#
# I: <s> 1 1 8 0 3  <e>
# P: <s> eleven thousand eight hundred three <e> <pad> <pad>
# T: <s> eleven thousand eight hundred three <e> <pad> <pad>   Ding!
#
# I: <s> 1 4 1 7 0  <e>
# P: <s> fourteen thousand one hundred seventy  <e> <pad>
# T: <s> fourteen thousand one hundred seventy  <e> <pad>   Ding!
#
# I: <s> 3 0 6 2  <e> <pad>
# P: <s> three thousand sixty two <e> <pad> <pad> <pad>
# T: <s> three thousand sixty two <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 3 9 8 9 5  <e>
# P: <s> thirty nine thousand eight hundred ninety five <e>
# T: <s> thirty nine thousand eight hundred ninety five <e>   Ding!
#
# I: <s> 3 3 5 4  <e> <pad>
# P: <s> three thousand three hundred forty four <e> <pad>
# T: <s> three thousand three hundred fifty four <e> <pad>
#
# I: <s> 7 5 2 8  <e> <pad>
# P: <s> seven thousand five hundred twenty eight <e> <pad>
# T: <s> seven thousand five hundred twenty eight <e> <pad>   Ding!
#
# I: <s> 1 2 8 3 4  <e>
# P: <s> twelve thousand eight hundred thirty four <e> <pad>
# T: <s> twelve thousand eight hundred thirty four <e> <pad>   Ding!
#
# I: <s> 2 1 4 7 0  <e>
# P: <s> twenty one thousand four hundred seventy  <e>
# T: <s> twenty one thousand four hundred seventy  <e>   Ding!
#
# I: <s> 2 5 1 4 0  <e>
# P: <s> twenty five thousand one hundred forty  <e>
# T: <s> twenty five thousand one hundred forty  <e>   Ding!
#
# I: <s> 3 3 8 6 2  <e>
# P: <s> thirty three thousand eight hundred sixty two <e>
# T: <s> thirty three thousand eight hundred sixty two <e>   Ding!
#
# I: <s> 3 0 1 1 6  <e>
# P: <s> thirty  thousand one hundred sixteen <e> <pad>
# T: <s> thirty  thousand one hundred sixteen <e> <pad>   Ding!
#
# I: <s> 1 1 3 1 8  <e>
# P: <s> eleven thousand three hundred eighteen <e> <pad> <pad>
# T: <s> eleven thousand three hundred eighteen <e> <pad> <pad>   Ding!
#
# I: <s> 3 7 1 4  <e> <pad>
# P: <s> three thousand seven hundred fourteen <e> <pad> <pad>
# T: <s> three thousand seven hundred fourteen <e> <pad> <pad>   Ding!
#
# I: <s> 2 2 7 3 0  <e>
# P: <s> twenty two thousand seven hundred thirty  <e>
# T: <s> twenty two thousand seven hundred thirty  <e>   Ding!
#
# I: <s> 3 6 3 7 5  <e>
# P: <s> thirty six thousand three hundred seventy five <e>
# T: <s> thirty six thousand three hundred seventy five <e>   Ding!
#
# I: <s> 9 3 6 1  <e> <pad>
# P: <s> nine thousand three hundred sixty one <e> <pad>
# T: <s> nine thousand three hundred sixty one <e> <pad>   Ding!
#
# I: <s> 3 3 7 4 9  <e>
# P: <s> thirty three thousand seven hundred forty nine <e>
# T: <s> thirty three thousand seven hundred forty nine <e>   Ding!
#
# I: <s> 1 7 1 5 2  <e>
# P: <s> seventeen thousand one hundred fifty two <e> <pad>
# T: <s> seventeen thousand one hundred fifty two <e> <pad>   Ding!
#
# I: <s> 3 0 1  <e> <pad> <pad>
# P: <s> three hundred one <e> <pad> <pad> <pad> <pad>
# T: <s> three hundred one <e> <pad> <pad> <pad> <pad>   Ding!
#
# I: <s> 1 6 0 2 4  <e>
# P: <s> sixteen thousand twenty four <e> <pad> <pad> <pad>
# T: <s> sixteen thousand twenty four <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 2 4 8 8 8  <e>
# P: <s> twenty four thousand eight hundred eighty eight <e>
# T: <s> twenty four thousand eight hundred eighty eight <e>   Ding!
#
# I: <s> 7 4 0 0  <e> <pad>
# P: <s> seven thousand four hundred <e> <pad> <pad> <pad>
# T: <s> seven thousand four hundred <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 2 8 5 1 5  <e>
# P: <s> twenty eight thousand five hundred fifteen <e> <pad>
# T: <s> twenty eight thousand five hundred fifteen <e> <pad>   Ding!
#
# I: <s> 2 7 9 3  <e> <pad>
# P: <s> two thousand seven hundred ninety three <e> <pad>
# T: <s> two thousand seven hundred ninety three <e> <pad>   Ding!
#
# I: <s> 3 2 9 7 0  <e>
# P: <s> thirty two thousand nine hundred seventy  <e>
# T: <s> thirty two thousand nine hundred seventy  <e>   Ding!
#
# I: <s> 1 2 7 6 4  <e>
# P: <s> twelve thousand seven hundred sixty four <e> <pad>
# T: <s> twelve thousand seven hundred sixty four <e> <pad>   Ding!
#
# I: <s> 2 7 8 2 2  <e>
# P: <s> twenty seven thousand eight hundred twenty two <e>
# T: <s> twenty seven thousand eight hundred twenty two <e>   Ding!
#
# I: <s> 1 9 8 8 6  <e>
# P: <s> nineteen thousand eight hundred eighty six <e> <pad>
# T: <s> nineteen thousand eight hundred eighty six <e> <pad>   Ding!
#
# I: <s> 3 2 0 2 7  <e>
# P: <s> thirty two thousand twenty seven <e> <pad> <pad>
# T: <s> thirty two thousand twenty seven <e> <pad> <pad>   Ding!
#
# I: <s> 5 0 0 6  <e> <pad>
# P: <s> five thousand six <e> <pad> <pad> <pad> <pad>
# T: <s> five thousand six <e> <pad> <pad> <pad> <pad>   Ding!
#
# I: <s> 2 0 9 9 0  <e>
# P: <s> twenty  thousand nine hundred ninety  <e>
# T: <s> twenty  thousand nine hundred ninety  <e>   Ding!
#
# I: <s> 1 5 2 6  <e> <pad>
# P: <s> one thousand five hundred twenty six <e> <pad>
# T: <s> one thousand five hundred twenty six <e> <pad>   Ding!
#
# I: <s> 2 8 7 3 2  <e>
# P: <s> twenty eight thousand seven hundred thirty two <e>
# T: <s> twenty eight thousand seven hundred thirty two <e>   Ding!
#
# I: <s> 3 7 6 9 0  <e>
# P: <s> thirty seven thousand six hundred ninety  <e>
# T: <s> thirty seven thousand six hundred ninety  <e>   Ding!
#
# I: <s> 1 3 1 8 4  <e>
# P: <s> thirteen thousand one hundred eighty four <e> <pad>
# T: <s> thirteen thousand one hundred eighty four <e> <pad>   Ding!
#
# I: <s> 3 2 0 0 2  <e>
# P: <s> thirty two thousand two <e> <pad> <pad> <pad>
# T: <s> thirty two thousand two <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 1 7 5 6 5  <e>
# P: <s> seventeen thousand five hundred sixty five <e> <pad>
# T: <s> seventeen thousand five hundred sixty five <e> <pad>   Ding!
#
# I: <s> 2 0 2 0  <e> <pad>
# P: <s> two thousand twenty  <e> <pad> <pad> <pad>
# T: <s> two thousand twenty  <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 2 1 5 4 1  <e>
# P: <s> twenty one thousand five hundred forty one <e>
# T: <s> twenty one thousand five hundred forty one <e>   Ding!
#
# I: <s> 8 9 5  <e> <pad> <pad>
# P: <s> eight hundred ninety five <e> <pad> <pad> <pad>
# T: <s> eight hundred ninety five <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 2 3 4 9 0  <e>
# P: <s> twenty three thousand four hundred ninety  <e>
# T: <s> twenty three thousand four hundred ninety  <e>   Ding!
#
# I: <s> 2 0 5 4 7  <e>
# P: <s> twenty  thousand five hundred forty seven <e>
# T: <s> twenty  thousand five hundred forty seven <e>   Ding!
#
# I: <s> 1 3 5 4 1  <e>
# P: <s> thirteen thousand five hundred forty one <e> <pad>
# T: <s> thirteen thousand five hundred forty one <e> <pad>   Ding!
#
# I: <s> 2 9 1 6 0  <e>
# P: <s> twenty nine thousand one hundred sixty  <e>
# T: <s> twenty nine thousand one hundred sixty  <e>   Ding!
#
# I: <s> 1 7 7 0 6  <e>
# P: <s> seventeen thousand seven hundred six <e> <pad> <pad>
# T: <s> seventeen thousand seven hundred six <e> <pad> <pad>   Ding!
#
# I: <s> 1 2 0 2 9  <e>
# P: <s> twelve thousand twenty nine <e> <pad> <pad> <pad>
# T: <s> twelve thousand twenty nine <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 2 7 3 5 4  <e>
# P: <s> twenty seven thousand three hundred fifty four <e>
# T: <s> twenty seven thousand three hundred fifty four <e>   Ding!
#
# I: <s> 2 6 3 7 3  <e>
# P: <s> twenty six thousand three hundred seventy three <e>
# T: <s> twenty six thousand three hundred seventy three <e>   Ding!
#
# I: <s> 2 6 6 6 5  <e>
# P: <s> twenty six thousand six hundred sixty five <e>
# T: <s> twenty six thousand six hundred sixty five <e>   Ding!
#
# I: <s> 9 7 7 3  <e> <pad>
# P: <s> nine thousand seven hundred seventy three <e> <pad>
# T: <s> nine thousand seven hundred seventy three <e> <pad>   Ding!
#
# I: <s> 1 2 8 0 2  <e>
# P: <s> twelve thousand eight hundred two <e> <pad> <pad>
# T: <s> twelve thousand eight hundred two <e> <pad> <pad>   Ding!
#
# I: <s> 3 6 0 1 1  <e>
# P: <s> thirty six thousand eleven <e> <pad> <pad> <pad>
# T: <s> thirty six thousand eleven <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 3 4 4 6 9  <e>
# P: <s> thirty four thousand four hundred sixty nine <e>
# T: <s> thirty four thousand four hundred sixty nine <e>   Ding!
#
# I: <s> 2 7 7 6 7  <e>
# P: <s> twenty seven thousand seven hundred sixty seven <e>
# T: <s> twenty seven thousand seven hundred sixty seven <e>   Ding!
#
# I: <s> 7 3 3 7  <e> <pad>
# P: <s> seven thousand three hundred thirty seven <e> <pad>
# T: <s> seven thousand three hundred thirty seven <e> <pad>   Ding!
#
# I: <s> 2 1 0 2 5  <e>
# P: <s> twenty one thousand twenty five <e> <pad> <pad>
# T: <s> twenty one thousand twenty five <e> <pad> <pad>   Ding!
#
# I: <s> 1 7 6 1 6  <e>
# P: <s> seventeen thousand six hundred sixteen <e> <pad> <pad>
# T: <s> seventeen thousand six hundred sixteen <e> <pad> <pad>   Ding!
#
# I: <s> 1 7 4 1 3  <e>
# P: <s> seventeen thousand four hundred thirteen <e> <pad> <pad>
# T: <s> seventeen thousand four hundred thirteen <e> <pad> <pad>   Ding!
#
# I: <s> 2 5 2 0 7  <e>
# P: <s> twenty five thousand two hundred seven <e> <pad>
# T: <s> twenty five thousand two hundred seven <e> <pad>   Ding!
#
# I: <s> 2 9 2 6 6  <e>
# P: <s> twenty nine thousand two hundred sixty six <e>
# T: <s> twenty nine thousand two hundred sixty six <e>   Ding!
#
# I: <s> 2 9 4 9 6  <e>
# P: <s> twenty nine thousand four hundred ninety six <e>
# T: <s> twenty nine thousand four hundred ninety six <e>   Ding!
#
# I: <s> 3 1 6 1 5  <e>
# P: <s> thirty one thousand six hundred fifteen <e> <pad>
# T: <s> thirty one thousand six hundred fifteen <e> <pad>   Ding!
#
# I: <s> 3 4 1 2 1  <e>
# P: <s> thirty four thousand one hundred twenty one <e>
# T: <s> thirty four thousand one hundred twenty one <e>   Ding!
#
# I: <s> 2 8 1 9 8  <e>
# P: <s> twenty eight thousand one hundred ninety eight <e>
# T: <s> twenty eight thousand one hundred ninety eight <e>   Ding!
#
# I: <s> 9 8 4 7  <e> <pad>
# P: <s> nine thousand eight hundred eighty seven <e> <pad>
# T: <s> nine thousand eight hundred forty seven <e> <pad>
#
# I: <s> 3 0 3 4 7  <e>
# P: <s> thirty  thousand three hundred forty seven <e>
# T: <s> thirty  thousand three hundred forty seven <e>   Ding!
#
# I: <s> 3 5 4 5 5  <e>
# P: <s> thirty five thousand four hundred fifty five <e>
# T: <s> thirty five thousand four hundred fifty five <e>   Ding!
#
# I: <s> 2 2 5 5 2  <e>
# P: <s> twenty two thousand five hundred fifty two <e>
# T: <s> twenty two thousand five hundred fifty two <e>   Ding!
#
# I: <s> 1 5 9 4 0  <e>
# P: <s> fifteen thousand nine hundred forty  <e> <pad>
# T: <s> fifteen thousand nine hundred forty  <e> <pad>   Ding!
#
# I: <s> 3 6 0 9 1  <e>
# P: <s> thirty six thousand ninety one <e> <pad> <pad>
# T: <s> thirty six thousand ninety one <e> <pad> <pad>   Ding!
#
# I: <s> 2 2 3 7 4  <e>
# P: <s> twenty two thousand three hundred seventy four <e>
# T: <s> twenty two thousand three hundred seventy four <e>   Ding!
#
# I: <s> 1 7 2 0 6  <e>
# P: <s> seventeen thousand two hundred six <e> <pad> <pad>
# T: <s> seventeen thousand two hundred six <e> <pad> <pad>   Ding!
#
# I: <s> 8 9 2 2  <e> <pad>
# P: <s> eight thousand nine hundred twenty two <e> <pad>
# T: <s> eight thousand nine hundred twenty two <e> <pad>   Ding!
#
# I: <s> 5 0 3 7  <e> <pad>
# P: <s> five thousand thirty seven <e> <pad> <pad> <pad>
# T: <s> five thousand thirty seven <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 3 5 8 6 7  <e>
# P: <s> thirty five thousand eight hundred seventy seven <e>
# T: <s> thirty five thousand eight hundred sixty seven <e>
#
# I: <s> 2 5 4 6 7  <e>
# P: <s> twenty five thousand four hundred sixty seven <e>
# T: <s> twenty five thousand four hundred sixty seven <e>   Ding!
#
# I: <s> 1 4 8 7 4  <e>
# P: <s> fourteen thousand eight hundred seventy four <e> <pad>
# T: <s> fourteen thousand eight hundred seventy four <e> <pad>   Ding!
#
# I: <s> 3 1 5 2 2  <e>
# P: <s> thirty one thousand five hundred twenty two <e>
# T: <s> thirty one thousand five hundred twenty two <e>   Ding!
#
# I: <s> 1 8 6 2 9  <e>
# P: <s> eighteen thousand six hundred twenty nine <e> <pad>
# T: <s> eighteen thousand six hundred twenty nine <e> <pad>   Ding!
#
# I: <s> 1 7 4 4 2  <e>
# P: <s> seventeen thousand four hundred forty two <e> <pad>
# T: <s> seventeen thousand four hundred forty two <e> <pad>   Ding!
#
# I: <s> 1 0 6 9 7  <e>
# P: <s> ten thousand six hundred ninety seven <e> <pad>
# T: <s> ten thousand six hundred ninety seven <e> <pad>   Ding!
#
# I: <s> 8 6 6 1  <e> <pad>
# P: <s> eight thousand six hundred sixty one <e> <pad>
# T: <s> eight thousand six hundred sixty one <e> <pad>   Ding!
#
# I: <s> 1 9 5 4 9  <e>
# P: <s> nineteen thousand five hundred forty nine <e> <pad>
# T: <s> nineteen thousand five hundred forty nine <e> <pad>   Ding!
#
# I: <s> 2 2 5 4 5  <e>
# P: <s> twenty two thousand five hundred forty five <e>
# T: <s> twenty two thousand five hundred forty five <e>   Ding!
#
# I: <s> 3 9 2 5  <e> <pad>
# P: <s> three thousand nine hundred twenty five <e> <pad>
# T: <s> three thousand nine hundred twenty five <e> <pad>   Ding!
#
# I: <s> 2 9 2 8 4  <e>
# P: <s> twenty nine thousand two hundred eighty four <e>
# T: <s> twenty nine thousand two hundred eighty four <e>   Ding!
#
# I: <s> 5 4 2  <e> <pad> <pad>
# P: <s> five hundred sixty two <e> <pad> <pad> <pad>
# T: <s> five hundred forty two <e> <pad> <pad> <pad>
#
# I: <s> 2 4 2 8 9  <e>
# P: <s> twenty four thousand two hundred eighty nine <e>
# T: <s> twenty four thousand two hundred eighty nine <e>   Ding!
#
# I: <s> 9 7 6 3  <e> <pad>
# P: <s> nine thousand seven hundred sixty three <e> <pad>
# T: <s> nine thousand seven hundred sixty three <e> <pad>   Ding!
#
# I: <s> 1 2 0 0 6  <e>
# P: <s> twelve thousand six <e> <pad> <pad> <pad> <pad>
# T: <s> twelve thousand six <e> <pad> <pad> <pad> <pad>   Ding!
#
# I: <s> 4 5 8 6  <e> <pad>
# P: <s> four thousand five hundred eighty six <e> <pad>
# T: <s> four thousand five hundred eighty six <e> <pad>   Ding!
#
# I: <s> 1 7 9 1 8  <e>
# P: <s> seventeen thousand nine hundred eighteen <e> <pad> <pad>
# T: <s> seventeen thousand nine hundred eighteen <e> <pad> <pad>   Ding!
#
# I: <s> 1 7 3 2 4  <e>
# P: <s> seventeen thousand three hundred thirty four <e> <pad>
# T: <s> seventeen thousand three hundred twenty four <e> <pad>
#
# I: <s> 3 1 9 5 2  <e>
# P: <s> thirty one thousand nine hundred fifty two <e>
# T: <s> thirty one thousand nine hundred fifty two <e>   Ding!
#
# I: <s> 2 0 9 5 4  <e>
# P: <s> twenty  thousand nine hundred fifty four <e>
# T: <s> twenty  thousand nine hundred fifty four <e>   Ding!
#
# I: <s> 3 8 3 4 2  <e>
# P: <s> thirty eight thousand three hundred forty two <e>
# T: <s> thirty eight thousand three hundred forty two <e>   Ding!
#
# I: <s> 1 3 1 9 7  <e>
# P: <s> thirteen thousand one hundred ninety seven <e> <pad>
# T: <s> thirteen thousand one hundred ninety seven <e> <pad>   Ding!
#
# I: <s> 2 0 5 6 8  <e>
# P: <s> twenty  thousand five hundred sixty eight <e>
# T: <s> twenty  thousand five hundred sixty eight <e>   Ding!
#
# I: <s> 1 9 4 4 3  <e>
# P: <s> nineteen thousand four hundred forty three <e> <pad>
# T: <s> nineteen thousand four hundred forty three <e> <pad>   Ding!
#
# I: <s> 1 6 9 5 9  <e>
# P: <s> sixteen thousand nine hundred fifty nine <e> <pad>
# T: <s> sixteen thousand nine hundred fifty nine <e> <pad>   Ding!
#
# I: <s> 2 2 5 7 5  <e>
# P: <s> twenty two thousand five hundred seventy five <e>
# T: <s> twenty two thousand five hundred seventy five <e>   Ding!
#
# I: <s> 1 2 4 9 6  <e>
# P: <s> twelve thousand four hundred ninety six <e> <pad>
# T: <s> twelve thousand four hundred ninety six <e> <pad>   Ding!
#
# I: <s> 6 2 5 5  <e> <pad>
# P: <s> six thousand two hundred fifty five <e> <pad>
# T: <s> six thousand two hundred fifty five <e> <pad>   Ding!
#
# I: <s> 2 4 0 7 2  <e>
# P: <s> twenty four thousand seventy two <e> <pad> <pad>
# T: <s> twenty four thousand seventy two <e> <pad> <pad>   Ding!
#
# I: <s> 1 2 5 1 8  <e>
# P: <s> twelve thousand five hundred eighteen <e> <pad> <pad>
# T: <s> twelve thousand five hundred eighteen <e> <pad> <pad>   Ding!
#
# I: <s> 2 9 6 7 5  <e>
# P: <s> twenty nine thousand six hundred seventy five <e>
# T: <s> twenty nine thousand six hundred seventy five <e>   Ding!
#
# I: <s> 3 8 4 5 5  <e>
# P: <s> thirty eight thousand four hundred fifty five <e>
# T: <s> thirty eight thousand four hundred fifty five <e>   Ding!
#
# I: <s> 6 7 8 6  <e> <pad>
# P: <s> six thousand seven hundred eighty six <e> <pad>
# T: <s> six thousand seven hundred eighty six <e> <pad>   Ding!
#
# I: <s> 2 0 8 0 7  <e>
# P: <s> twenty  thousand eight hundred seven <e> <pad>
# T: <s> twenty  thousand eight hundred seven <e> <pad>   Ding!
#
# I: <s> 2 0 1 9 7  <e>
# P: <s> twenty  thousand one hundred ninety nine <e>
# T: <s> twenty  thousand one hundred ninety seven <e>
#
# I: <s> 3 4 0 0 4  <e>
# P: <s> thirty four thousand four <e> <pad> <pad> <pad>
# T: <s> thirty four thousand four <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 3 5 7 2 9  <e>
# P: <s> thirty five thousand seven hundred twenty nine <e>
# T: <s> thirty five thousand seven hundred twenty nine <e>   Ding!
#
# I: <s> 3 5 0 3 4  <e>
# P: <s> thirty five thousand thirty four <e> <pad> <pad>
# T: <s> thirty five thousand thirty four <e> <pad> <pad>   Ding!
#
# I: <s> 2 5 3 3 3  <e>
# P: <s> twenty five thousand three hundred thirty three <e>
# T: <s> twenty five thousand three hundred thirty three <e>   Ding!
#
# I: <s> 1 7 5 4 2  <e>
# P: <s> seventeen thousand five hundred forty two <e> <pad>
# T: <s> seventeen thousand five hundred forty two <e> <pad>   Ding!
#
# I: <s> 8 6 7 3  <e> <pad>
# P: <s> eight thousand six hundred seventy three <e> <pad>
# T: <s> eight thousand six hundred seventy three <e> <pad>   Ding!
#
# I: <s> 2 1 9 2 9  <e>
# P: <s> twenty one thousand nine hundred twenty nine <e>
# T: <s> twenty one thousand nine hundred twenty nine <e>   Ding!
#
# I: <s> 1 7 3 6 9  <e>
# P: <s> seventeen thousand three hundred ninety nine <e> <pad>
# T: <s> seventeen thousand three hundred sixty nine <e> <pad>
#
# I: <s> 3 6 8 9 8  <e>
# P: <s> thirty six thousand eight hundred ninety eight <e>
# T: <s> thirty six thousand eight hundred ninety eight <e>   Ding!
#
# I: <s> 2 9 4 7 3  <e>
# P: <s> twenty nine thousand four hundred seventy three <e>
# T: <s> twenty nine thousand four hundred seventy three <e>   Ding!
#
# I: <s> 3 8 1 7 8  <e>
# P: <s> thirty eight thousand one hundred seventy eight <e>
# T: <s> thirty eight thousand one hundred seventy eight <e>   Ding!
#
# I: <s> 3 4 5 5 8  <e>
# P: <s> thirty four thousand five hundred fifty eight <e>
# T: <s> thirty four thousand five hundred fifty eight <e>   Ding!
#
# I: <s> 2 2 9 5 3  <e>
# P: <s> twenty two thousand nine hundred fifty three <e>
# T: <s> twenty two thousand nine hundred fifty three <e>   Ding!
#
# I: <s> 3 7 3 3 2  <e>
# P: <s> thirty seven thousand three hundred thirty two <e>
# T: <s> thirty seven thousand three hundred thirty two <e>   Ding!
#
# I: <s> 2 7 6 1 6  <e>
# P: <s> twenty seven thousand six hundred sixteen <e> <pad>
# T: <s> twenty seven thousand six hundred sixteen <e> <pad>   Ding!
#
# I: <s> 2 8 3 2 4  <e>
# P: <s> twenty eight thousand three hundred thirty four <e>
# T: <s> twenty eight thousand three hundred twenty four <e>
#
# I: <s> 3 3 0 7 7  <e>
# P: <s> thirty three thousand seventy seven <e> <pad> <pad>
# T: <s> thirty three thousand seventy seven <e> <pad> <pad>   Ding!
#
# I: <s> 3 8 0 7 3  <e>
# P: <s> thirty eight thousand seventy three <e> <pad> <pad>
# T: <s> thirty eight thousand seventy three <e> <pad> <pad>   Ding!
#
# I: <s> 3 4 2 7 9  <e>
# P: <s> thirty four thousand two hundred seventy nine <e>
# T: <s> thirty four thousand two hundred seventy nine <e>   Ding!
#
# I: <s> 3 1 7 2 1  <e>
# P: <s> thirty one thousand seven hundred twenty one <e>
# T: <s> thirty one thousand seven hundred twenty one <e>   Ding!
#
# I: <s> 2 3 0 0 7  <e>
# P: <s> twenty three thousand seven <e> <pad> <pad> <pad>
# T: <s> twenty three thousand seven <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 6 1 6 6  <e> <pad>
# P: <s> six thousand one hundred sixty six <e> <pad>
# T: <s> six thousand one hundred sixty six <e> <pad>   Ding!
#
# I: <s> 1 7 5 5 5  <e>
# P: <s> seventeen thousand five hundred fifty five <e> <pad>
# T: <s> seventeen thousand five hundred fifty five <e> <pad>   Ding!
#
# I: <s> 3 9 0 4 0  <e>
# P: <s> thirty nine thousand forty  <e> <pad> <pad>
# T: <s> thirty nine thousand forty  <e> <pad> <pad>   Ding!
#
# I: <s> 1 7 5 9 2  <e>
# P: <s> seventeen thousand five hundred ninety two <e> <pad>
# T: <s> seventeen thousand five hundred ninety two <e> <pad>   Ding!
#
# I: <s> 3 4 0 4 3  <e>
# P: <s> thirty four thousand forty three <e> <pad> <pad>
# T: <s> thirty four thousand forty three <e> <pad> <pad>   Ding!
#
# I: <s> 2 4 2 3 2  <e>
# P: <s> twenty four thousand two hundred twenty two <e>
# T: <s> twenty four thousand two hundred thirty two <e>
#
# I: <s> 1 6 2 3 1  <e>
# P: <s> sixteen thousand two hundred thirty one <e> <pad>
# T: <s> sixteen thousand two hundred thirty one <e> <pad>   Ding!
#
# I: <s> 2 0 0 7 1  <e>
# P: <s> twenty  thousand seventy one <e> <pad> <pad>
# T: <s> twenty  thousand seventy one <e> <pad> <pad>   Ding!
#
# I: <s> 8 3 7 3  <e> <pad>
# P: <s> eight thousand three hundred seventy three <e> <pad>
# T: <s> eight thousand three hundred seventy three <e> <pad>   Ding!
#
# I: <s> 1 7 9 8 2  <e>
# P: <s> seventeen thousand nine hundred eighty two <e> <pad>
# T: <s> seventeen thousand nine hundred eighty two <e> <pad>   Ding!
#
# I: <s> 3 0 7 1 3  <e>
# P: <s> thirty  thousand seven hundred thirteen <e> <pad>
# T: <s> thirty  thousand seven hundred thirteen <e> <pad>   Ding!
#
# I: <s> 3 7 8 7 8  <e>
# P: <s> thirty seven thousand eight hundred seventy eight <e>
# T: <s> thirty seven thousand eight hundred seventy eight <e>   Ding!
#
# I: <s> 3 9 7 9 8  <e>
# P: <s> thirty nine thousand seven hundred ninety eight <e>
# T: <s> thirty nine thousand seven hundred ninety eight <e>   Ding!
#
# I: <s> 1 3 7 4 5  <e>
# P: <s> thirteen thousand seven hundred forty five <e> <pad>
# T: <s> thirteen thousand seven hundred forty five <e> <pad>   Ding!
#
# I: <s> 2 1 5 8 6  <e>
# P: <s> twenty one thousand five hundred eighty six <e>
# T: <s> twenty one thousand five hundred eighty six <e>   Ding!
#
# I: <s> 2 4 7 8 5  <e>
# P: <s> twenty four thousand seven hundred eighty five <e>
# ...
#
# I: <s> 3 6 0 5 2  <e>
# P: <s> thirty six thousand fifty two <e> <pad> <pad>
# T: <s> thirty six thousand fifty two <e> <pad> <pad>   Ding!
#
# I: <s> 4 2 7 7  <e> <pad>
# P: <s> four thousand two hundred seventy seven <e> <pad>
# T: <s> four thousand two hundred seventy seven <e> <pad>   Ding!
#
# I: <s> 6 2 7 0  <e> <pad>
# P: <s> six thousand two hundred seventy  <e> <pad>
# T: <s> six thousand two hundred seventy  <e> <pad>   Ding!
#
# I: <s> 9 3 6  <e> <pad> <pad>
# P: <s> nine hundred thirty six <e> <pad> <pad> <pad>
# T: <s> nine hundred thirty six <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 2 4 1 8 4  <e>
# P: <s> twenty four thousand one hundred eighty four <e>
# T: <s> twenty four thousand one hundred eighty four <e>   Ding!
#
# I: <s> 1 0 4 3 5  <e>
# P: <s> ten thousand four hundred thirty five <e> <pad>
# T: <s> ten thousand four hundred thirty five <e> <pad>   Ding!
#
# I: <s> 3 4 1 1 3  <e>
# P: <s> thirty four thousand one hundred thirteen <e> <pad>
# T: <s> thirty four thousand one hundred thirteen <e> <pad>   Ding!
#
# I: <s> 2 2 9 0 6  <e>
# P: <s> twenty two thousand nine hundred six <e> <pad>
# T: <s> twenty two thousand nine hundred six <e> <pad>   Ding!
#
# I: <s> 3 8 4  <e> <pad> <pad>
# P: <s> three hundred eighty four <e> <pad> <pad> <pad>
# T: <s> three hundred eighty four <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 2 4 6 1 1  <e>
# P: <s> twenty four thousand six hundred eleven <e> <pad>
# T: <s> twenty four thousand six hundred eleven <e> <pad>   Ding!
#
# I: <s> 3 4 2 1 8  <e>
# P: <s> thirty four thousand two hundred eighteen <e> <pad>
# T: <s> thirty four thousand two hundred eighteen <e> <pad>   Ding!
#
# I: <s> 5 7 4 8  <e> <pad>
# P: <s> five thousand seven hundred eighty eight <e> <pad>
# T: <s> five thousand seven hundred forty eight <e> <pad>
#
# I: <s> 1 4 4 1 2  <e>
# P: <s> fourteen thousand four hundred twelve <e> <pad> <pad>
# T: <s> fourteen thousand four hundred twelve <e> <pad> <pad>   Ding!
#
# I: <s> 2 7 1 7 0  <e>
# P: <s> twenty seven thousand one hundred seventy  <e>
# T: <s> twenty seven thousand one hundred seventy  <e>   Ding!
#
# I: <s> 3 6 0 1 9  <e>
# P: <s> thirty six thousand nineteen <e> <pad> <pad> <pad>
# T: <s> thirty six thousand nineteen <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 2 3 9 5 7  <e>
# P: <s> twenty three thousand nine hundred fifty seven <e>
# T: <s> twenty three thousand nine hundred fifty seven <e>   Ding!
#
# I: <s> 3 0 7 4 9  <e>
# P: <s> thirty  thousand seven hundred forty nine <e>
# T: <s> thirty  thousand seven hundred forty nine <e>   Ding!
#
# I: <s> 1 6 5 3 5  <e>
# P: <s> sixteen thousand five hundred thirty five <e> <pad>
# T: <s> sixteen thousand five hundred thirty five <e> <pad>   Ding!
#
# I: <s> 1 8 2 4  <e> <pad>
# P: <s> one thousand eight hundred twenty four <e> <pad>
# T: <s> one thousand eight hundred twenty four <e> <pad>   Ding!
#
# I: <s> 3 4 5 2 9  <e>
# P: <s> thirty four thousand five hundred twenty nine <e>
# T: <s> thirty four thousand five hundred twenty nine <e>   Ding!
#
# I: <s> 3 8 4 0 2  <e>
# P: <s> thirty eight thousand four hundred two <e> <pad>
# T: <s> thirty eight thousand four hundred two <e> <pad>   Ding!
#
# I: <s> 7 4 5 1  <e> <pad>
# P: <s> seven thousand four hundred fifty one <e> <pad>
# T: <s> seven thousand four hundred fifty one <e> <pad>   Ding!
#
# I: <s> 1 1 7 7 1  <e>
# P: <s> eleven thousand seven hundred seventy one <e> <pad>
# T: <s> eleven thousand seven hundred seventy one <e> <pad>   Ding!
#
# I: <s> 1 5 1 2 5  <e>
# P: <s> fifteen thousand one hundred twenty five <e> <pad>
# T: <s> fifteen thousand one hundred twenty five <e> <pad>   Ding!
#
# I: <s> 1 0 7 9 4  <e>
# P: <s> ten thousand seven hundred ninety three <e> <pad>
# T: <s> ten thousand seven hundred ninety four <e> <pad>
#
# I: <s> 1 2 1 0 6  <e>
# P: <s> twelve thousand one hundred six <e> <pad> <pad>
# T: <s> twelve thousand one hundred six <e> <pad> <pad>   Ding!
#
# I: <s> 3 5 2 5 7  <e>
# P: <s> thirty five thousand two hundred fifty seven <e>
# T: <s> thirty five thousand two hundred fifty seven <e>   Ding!
#
# I: <s> 2 3 3 1 0  <e>
# P: <s> twenty three thousand three hundred ten <e> <pad>
# T: <s> twenty three thousand three hundred ten <e> <pad>   Ding!
#
# I: <s> 1 5 4 4 1  <e>
# P: <s> fifteen thousand four hundred forty one <e> <pad>
# T: <s> fifteen thousand four hundred forty one <e> <pad>   Ding!
#
# I: <s> 3 4 7 9 4  <e>
# P: <s> thirty four thousand seven hundred ninety four <e>
# T: <s> thirty four thousand seven hundred ninety four <e>   Ding!
#
# I: <s> 2 6 5 4 0  <e>
# P: <s> twenty six thousand five hundred forty  <e>
# T: <s> twenty six thousand five hundred forty  <e>   Ding!
#
# I: <s> 6 8 7 6  <e> <pad>
# P: <s> six thousand eight hundred seventy six <e> <pad>
# T: <s> six thousand eight hundred seventy six <e> <pad>   Ding!
#
# I: <s> 1 9 9 8 6  <e>
# P: <s> nineteen thousand nine hundred eighty six <e> <pad>
# T: <s> nineteen thousand nine hundred eighty six <e> <pad>   Ding!
#
# I: <s> 5 8 1 4  <e> <pad>
# P: <s> five thousand eight hundred fourteen <e> <pad> <pad>
# T: <s> five thousand eight hundred fourteen <e> <pad> <pad>   Ding!
#
# I: <s> 1 3 8 9 6  <e>
# P: <s> thirteen thousand eight hundred ninety six <e> <pad>
# T: <s> thirteen thousand eight hundred ninety six <e> <pad>   Ding!
#
# I: <s> 9 8 5 7  <e> <pad>
# P: <s> nine thousand eight hundred fifty seven <e> <pad>
# T: <s> nine thousand eight hundred fifty seven <e> <pad>   Ding!
#
# I: <s> 1 2 9 4 4  <e>
# P: <s> twelve thousand nine hundred forty four <e> <pad>
# T: <s> twelve thousand nine hundred forty four <e> <pad>   Ding!
#
# I: <s> 2 1 6 2 1  <e>
# P: <s> twenty one thousand six hundred twenty one <e>
# T: <s> twenty one thousand six hundred twenty one <e>   Ding!
#
# I: <s> 4 4 9 3  <e> <pad>
# P: <s> four thousand four hundred ninety three <e> <pad>
# T: <s> four thousand four hundred ninety three <e> <pad>   Ding!
#
# I: <s> 1 1 5 2 6  <e>
# P: <s> eleven thousand five hundred twenty six <e> <pad>
# T: <s> eleven thousand five hundred twenty six <e> <pad>   Ding!
#
# I: <s> 2 0 3 0 8  <e>
# P: <s> twenty  thousand three hundred eight <e> <pad>
# T: <s> twenty  thousand three hundred eight <e> <pad>   Ding!
#
# I: <s> 3 3 4 3 3  <e>
# P: <s> thirty three thousand four hundred thirty three <e>
# T: <s> thirty three thousand four hundred thirty three <e>   Ding!
#
# I: <s> 1 9 9 5  <e> <pad>
# P: <s> one thousand nine hundred ninety five <e> <pad>
# T: <s> one thousand nine hundred ninety five <e> <pad>   Ding!
#
# I: <s> 5 7 0 8  <e> <pad>
# P: <s> five thousand seven hundred eight <e> <pad> <pad>
# T: <s> five thousand seven hundred eight <e> <pad> <pad>   Ding!
#
# I: <s> 1 1 9 4 3  <e>
# P: <s> eleven thousand nine hundred forty three <e> <pad>
# T: <s> eleven thousand nine hundred forty three <e> <pad>   Ding!
#
# I: <s> 1 9 2 2 8  <e>
# P: <s> nineteen thousand two hundred twenty eight <e> <pad>
# T: <s> nineteen thousand two hundred twenty eight <e> <pad>   Ding!
#
# I: <s> 3 9 4 1 8  <e>
# P: <s> thirty nine thousand four hundred eighteen <e> <pad>
# T: <s> thirty nine thousand four hundred eighteen <e> <pad>   Ding!
#
# I: <s> 3 9 4 0 9  <e>
# P: <s> thirty nine thousand four hundred nine <e> <pad>
# T: <s> thirty nine thousand four hundred nine <e> <pad>   Ding!
#
# I: <s> 2 3 9 4 1  <e>
# P: <s> twenty three thousand nine hundred forty one <e>
# T: <s> twenty three thousand nine hundred forty one <e>   Ding!
#
# I: <s> 2 3 6 5 5  <e>
# P: <s> twenty three thousand six hundred fifty five <e>
# T: <s> twenty three thousand six hundred fifty five <e>   Ding!
#
# I: <s> 3 7 7 5 1  <e>
# P: <s> thirty seven thousand seven hundred fifty one <e>
# T: <s> thirty seven thousand seven hundred fifty one <e>   Ding!
#
# I: <s> 2 2 8 1 3  <e>
# P: <s> twenty two thousand eight hundred thirteen <e> <pad>
# T: <s> twenty two thousand eight hundred thirteen <e> <pad>   Ding!
#
# I: <s> 2 9 0 7  <e> <pad>
# P: <s> two thousand nine hundred seven <e> <pad> <pad>
# T: <s> two thousand nine hundred seven <e> <pad> <pad>   Ding!
#
# I: <s> 3 7 1 1  <e> <pad>
# P: <s> three thousand seven hundred eleven <e> <pad> <pad>
# T: <s> three thousand seven hundred eleven <e> <pad> <pad>   Ding!
#
# I: <s> 3 2 5 3 1  <e>
# P: <s> thirty two thousand five hundred thirty one <e>
# T: <s> thirty two thousand five hundred thirty one <e>   Ding!
#
# I: <s> 3 2 8 8 3  <e>
# P: <s> thirty two thousand eight hundred eighty three <e>
# T: <s> thirty two thousand eight hundred eighty three <e>   Ding!
#
# I: <s> 2 9 4 1 0  <e>
# P: <s> twenty nine thousand four hundred ten <e> <pad>
# T: <s> twenty nine thousand four hundred ten <e> <pad>   Ding!
#
# I: <s> 3 2 0 1 8  <e>
# P: <s> thirty two thousand eighteen <e> <pad> <pad> <pad>
# T: <s> thirty two thousand eighteen <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 9 8 6 5  <e> <pad>
# P: <s> nine thousand eight hundred sixty five <e> <pad>
# T: <s> nine thousand eight hundred sixty five <e> <pad>   Ding!
#
# I: <s> 4 2 5 8  <e> <pad>
# P: <s> four thousand two hundred fifty eight <e> <pad>
# T: <s> four thousand two hundred fifty eight <e> <pad>   Ding!
#
# I: <s> 1 7 6 4 7  <e>
# P: <s> seventeen thousand six hundred forty seven <e> <pad>
# T: <s> seventeen thousand six hundred forty seven <e> <pad>   Ding!
#
# I: <s> 1 1 4 5 9  <e>
# P: <s> eleven thousand four hundred fifty nine <e> <pad>
# T: <s> eleven thousand four hundred fifty nine <e> <pad>   Ding!
#
# I: <s> 1 4 7 8  <e> <pad>
# P: <s> one thousand four hundred seventy eight <e> <pad>
# T: <s> one thousand four hundred seventy eight <e> <pad>   Ding!
#
# I: <s> 1 5 0 1 9  <e>
# P: <s> fifteen thousand nineteen <e> <pad> <pad> <pad> <pad>
# T: <s> fifteen thousand nineteen <e> <pad> <pad> <pad> <pad>   Ding!
#
# I: <s> 2 9 7 3 3  <e>
# P: <s> twenty nine thousand seven hundred thirty three <e>
# T: <s> twenty nine thousand seven hundred thirty three <e>   Ding!
#
# I: <s> 2 9 5 1 3  <e>
# P: <s> twenty nine thousand five hundred thirteen <e> <pad>
# T: <s> twenty nine thousand five hundred thirteen <e> <pad>   Ding!
#
# I: <s> 3 4 6 5 5  <e>
# P: <s> thirty four thousand six hundred fifty five <e>
# T: <s> thirty four thousand six hundred fifty five <e>   Ding!
#
# I: <s> 1 8 2 5 1  <e>
# P: <s> eighteen thousand two hundred fifty one <e> <pad>
# T: <s> eighteen thousand two hundred fifty one <e> <pad>   Ding!
#
# I: <s> 1 2 4 9 8  <e>
# P: <s> twelve thousand four hundred ninety eight <e> <pad>
# T: <s> twelve thousand four hundred ninety eight <e> <pad>   Ding!
#
# I: <s> 1 8 0 2 7  <e>
# P: <s> eighteen thousand twenty seven <e> <pad> <pad> <pad>
# T: <s> eighteen thousand twenty seven <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 1 1 5 9 6  <e>
# P: <s> eleven thousand five hundred ninety six <e> <pad>
# T: <s> eleven thousand five hundred ninety six <e> <pad>   Ding!
#
# I: <s> 3 8 1 6 6  <e>
# P: <s> thirty eight thousand one hundred sixty six <e>
# T: <s> thirty eight thousand one hundred sixty six <e>   Ding!
#
# I: <s> 8 0 3 0  <e> <pad>
# P: <s> eight thousand thirty  <e> <pad> <pad> <pad>
# T: <s> eight thousand thirty  <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 3 7 1 5 8  <e>
# P: <s> thirty seven thousand one hundred fifty eight <e>
# T: <s> thirty seven thousand one hundred fifty eight <e>   Ding!
#
# I: <s> 1 8 4 1 3  <e>
# P: <s> eighteen thousand four hundred thirteen <e> <pad> <pad>
# T: <s> eighteen thousand four hundred thirteen <e> <pad> <pad>   Ding!
#
# I: <s> 8 9 0  <e> <pad> <pad>
# P: <s> eight hundred ninety  <e> <pad> <pad> <pad>
# T: <s> eight hundred ninety  <e> <pad> <pad> <pad>   Ding!
#
# I: <s> 2 7 0 9 3  <e>
# P: <s> twenty seven thousand ninety three <e> <pad> <pad>
# T: <s> twenty seven thousand ninety three <e> <pad> <pad>   Ding!
#
# I: <s> 1 0 8 0 4  <e>
# P: <s> ten thousand eight hundred four <e> <pad> <pad>
# T: <s> ten thousand eight hundred four <e> <pad> <pad>   Ding!
#
# I: <s> 2 4 2 1 4  <e>
# P: <s> twenty four thousand two hundred fourteen <e> <pad>
# T: <s> twenty four thousand two hundred fourteen <e> <pad>   Ding!
#
# I: <s> 3 9  <e> <pad> <pad> <pad>
# P: <s> thirty nine <e> <pad> <pad> <pad> <pad> <pad>
# T: <s> thirty nine <e> <pad> <pad> <pad> <pad> <pad>   Ding!
#
# I: <s> 1 5 4 2 6  <e>
# P: <s> fifteen thousand four hundred twenty six <e> <pad>
# T: <s> fifteen thousand four hundred twenty six <e> <pad>   Ding!
#
# I: <s> 3 1 7 7 1  <e>
# P: <s> thirty one thousand seven hundred seventy one <e>
# T: <s> thirty one thousand seven hundred seventy one <e>   Ding!
#
# I: <s> 4 8 8 4  <e> <pad>
# P: <s> four thousand eight hundred eighty four <e> <pad>
# T: <s> four thousand eight hundred eighty four <e> <pad>   Ding!
#
# I: <s> 1 4 2 2 8  <e>
# P: <s> fourteen thousand two hundred twenty eight <e> <pad>
# T: <s> fourteen thousand two hundred twenty eight <e> <pad>   Ding!
#
# I: <s> 7 8 9 7  <e> <pad>
# P: <s> seven thousand eight hundred ninety seven <e> <pad>
# T: <s> seven thousand eight hundred ninety seven <e> <pad>   Ding!
#
# I: <s> 3 0 4 1 2  <e>
# P: <s> thirty  thousand four hundred twelve <e> <pad>
# T: <s> thirty  thousand four hundred twelve <e> <pad>   Ding!
#
# I: <s> 5 2 8 9  <e> <pad>
# P: <s> five thousand two hundred eighty nine <e> <pad>
# T: <s> five thousand two hundred eighty nine <e> <pad>   Ding!
#
# I: <s> 8 4 9 2  <e> <pad>
# P: <s> eight thousand four hundred ninety two <e> <pad>
# T: <s> eight thousand four hundred ninety two <e> <pad>   Ding!
#
# I: <s> 2 0 7 5 3  <e>
# P: <s> twenty  thousand seven hundred fifty three <e>
# T: <s> twenty  thousand seven hundred fifty three <e>   Ding!
#
# I: <s> 3 0 2 3  <e> <pad>
# P: <s> three thousand twenty two <e> <pad> <pad> <pad>
# T: <s> three thousand twenty three <e> <pad> <pad> <pad>
#
# I: <s> 1 8 5 5  <e> <pad>
# P: <s> one thousand eight hundred fifty five <e> <pad>
# T: <s> one thousand eight hundred fifty five <e> <pad>   Ding!
#
# I: <s> 3 2 4 3 0  <e>
# P: <s> thirty two thousand four hundred thirty  <e>
# T: <s> thirty two thousand four hundred thirty  <e>   Ding!
#
# I: <s> 1 8 4 9 7  <e>
# P: <s> eighteen thousand four hundred ninety seven <e> <pad>
# T: <s> eighteen thousand four hundred ninety seven <e> <pad>   Ding!
#
# I: <s> 3 7 2 5 8  <e>
# P: <s> thirty seven thousand two hundred eighty eight <e>
# T: <s> thirty seven thousand two hundred fifty eight <e>
#
# I: <s> 3 5 5 9 6  <e>
# P: <s> thirty five thousand five hundred ninety six <e>
# T: <s> thirty five thousand five hundred ninety six <e>   Ding!
#
# I: <s> 2 2 0 2 1  <e>
# P: <s> twenty two thousand twenty one <e> <pad> <pad>
# T: <s> twenty two thousand twenty one <e> <pad> <pad>   Ding!
#
# I: <s> 2 7 4 2 2  <e>
# P: <s> twenty seven thousand four hundred twenty two <e>
# T: <s> twenty seven thousand four hundred twenty two <e>   Ding!
#
# I: <s> 2 7 7 8 4  <e>
# P: <s> twenty seven thousand seven hundred eighty four <e>
# T: <s> twenty seven thousand seven hundred eighty four <e>   Ding!
#
# I: <s> 6 1 5 2  <e> <pad>
# P: <s> six thousand one hundred fifty two <e> <pad>
# T: <s> six thousand one hundred fifty two <e> <pad>   Ding!
#
# I: <s> 3 4 2 8 5  <e>
# P: <s> thirty four thousand two hundred eighty five <e>
# T: <s> thirty four thousand two hundred eighty five <e>   Ding!
#
# I: <s> 3 7 0 6 7  <e>
# P: <s> thirty seven thousand sixty seven <e> <pad> <pad>
# T: <s> thirty seven thousand sixty seven <e> <pad> <pad>   Ding!
#
# I: <s> 1 2 6 9 8  <e>
# P: <s> twelve thousand six hundred ninety eight <e> <pad>
# T: <s> twelve thousand six hundred ninety eight <e> <pad>   Ding!
#
# I: <s> 3 4 5 1 1  <e>
# P: <s> thirty four thousand five hundred eleven <e> <pad>
# T: <s> thirty four thousand five hundred eleven <e> <pad>   Ding!
#
# I: <s> 2 3 2 5 1  <e>
# P: <s> twenty three thousand two hundred fifty one <e>
# T: <s> twenty three thousand two hundred fifty one <e>   Ding!
#
# I: <s> 2 9 6 6 9  <e>
# P: <s> twenty nine thousand six hundred sixty nine <e>
# T: <s> twenty nine thousand six hundred sixty nine <e>   Ding!
#
# I: <s> 3 8 3 3 5  <e>
# P: <s> thirty eight thousand three hundred thirty five <e>
# T: <s> thirty eight thousand three hundred thirty five <e>   Ding!
#
# I: <s> 3 7 5 9 5  <e>
# P: <s> thirty seven thousand five hundred ninety five <e>
# T: <s> thirty seven thousand five hundred ninety five <e>   Ding!
#
#
#  Correct: 891, Total: 928, Acuuracy: 0.9601293103448276
